# %% [markdown]
# # ML in Genomics
# ## LSTM-2 Training
# ### Team Members:
#     1. Hrishikesh Mahajan
#     2. Pratik Kamble
#     3. Smridhi Bhat
#     4. Yash Shekhadar

# %%
# Basic Imports
import gzip as gz
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from random import random
import pickle as pkl

# Keras Imports 
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Masking
from keras.regularizers import l2
from keras.layers import Dropout
from keras import optimizers
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
f = gz.GzipFile("/content/drive/MyDrive/MLG/CULLPDB-Train.npy.gz", "r")
train_raw = np.load(f)
train_data = train_raw.reshape((len(train_raw), 700, 57))
train_x = train_data[:, :, 0:21]
train_y = train_data[:, :, 22:30]

# %%
f = gz.GzipFile("/content/drive/MyDrive/MLG/CULLPDB-Test.npy.gz", "r")
test_raw = np.load(f)
test_data = test_raw.reshape((len(test_raw), 700, 57))
test_x = test_data[:, :, 0:21]
test_y = test_data[:, :, 22:30]

# %%
model = Sequential()
model.add(Masking(mask_value=0., input_shape=(700, 21)))
model.add(LSTM(64, return_sequences=True))
model.add(LSTM(64, return_sequences=True))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc',  'mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  masking (Masking)           (None, 700, 21)           0
#
#  lstm (LSTM)                 (None, 700, 64)           22016
#
#  lstm_1 (LSTM)               (None, 700, 64)           33024
#
#  dense (Dense)               (None, 700, 16)           1040
#
#  dense_1 (Dense)             (None, 700, 8)            136
#
# =================================================================
# Total params: 56,216
# Trainable params: 56,216
# Non-trainable params: 0
# _________________________________________________________________

# %%
filepath = '/content/drive/MyDrive/MLG/Model-2/Model-2.hdf5'
checkpoint = ModelCheckpoint(filepath=filepath, 
                             monitor='val_loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')

# %%
history = model.fit(train_x, train_y, epochs=40, validation_data = (test_x, test_y), batch_size=32,callbacks=[checkpoint])
# Out:
# Epoch 1/40
# 168/168 [==============================] - ETA: 0s - loss: 0.5219 - acc: 0.3478 - mae: 0.1958
# Epoch 1: val_loss improved from inf to 0.39564, saving model to /content/drive/MyDrive/MLG/Model-2/Model-2.hdf5
# 168/168 [==============================] - 50s 216ms/step - loss: 0.5219 - acc: 0.3478 - mae: 0.1958 - val_loss: 0.3956 - val_acc: 0.3172 - val_mae: 0.1945
# Epoch 2/40
# 168/168 [==============================] - ETA: 0s - loss: 0.4881 - acc: 0.3730 - mae: 0.1878
# Epoch 2: val_loss improved from 0.39564 to 0.37603, saving model to /content/drive/MyDrive/MLG/Model-2/Model-2.hdf5
# 168/168 [==============================] - 33s 195ms/step - loss: 0.4881 - acc: 0.3730 - mae: 0.1878 - val_loss: 0.3760 - val_acc: 0.3625 - val_mae: 0.1867
# Epoch 3/40
# 168/168 [==============================] - ETA: 0s - loss: 0.4657 - acc: 0.4173 - mae: 0.1800
# Epoch 3: val_loss improved from 0.37603 to 0.36397, saving model to /content/drive/MyDrive/MLG/Model-2/Model-2.hdf5
# 168/168 [==============================] - 33s 197ms/step - loss: 0.4657 - acc: 0.4173 - mae: 0.1800 - val_loss: 0.3640 - val_acc: 0.4078 - val_mae: 0.1786
# Epoch 4/40
# 168/168 [==============================] - ETA: 0s - loss: 0.4578 - acc: 0.4327 - mae: 0.1763
# Epoch 4: val_loss improved from 0.36397 to 0.36162, saving model to /content/drive/MyDrive/MLG/Model-2/Model-2.hdf5
# 168/168 [==============================] - 33s 198ms/step - loss: 0.4578 - acc: 0.4327 - mae: 0.1763 - val_loss: 0.3616 - val_acc: 0.4114 - val_mae: 0.1772
# Epoch 5/40
# 168/168 [==============================] - ETA: 0s - loss: 0.4511 - acc: 0.4457 - mae: 0.1737
# Epoch 5: val_loss improved from 0.36162 to 0.35718, saving model to /content/drive/MyDrive/MLG/Model-2/Model-2.hdf5
# 168/168 [==============================] - 33s 196ms/step - loss: 0.4511 - acc: 0.4457 - mae: 0.1737 - val_loss: 0.3572 - val_acc: 0.4255 - val_mae: 0.1751
# Epoch 6/40
# 168/168 [==============================] - ETA: 0s - loss: 0.4493 - acc: 0.4490 - mae: 0.1726
# Epoch 6: val_loss improved from 0.35718 to 0.35375, saving model to /content/drive/MyDrive/MLG/Model-2/Model-2.hdf5
# 168/168 [==============================] - 33s 197ms/step - loss: 0.4493 - acc: 0.4490 - mae: 0.1726 - val_loss: 0.3538 - val_acc: 0.4335 - val_mae: 0.1750
# Epoch 7/40
# 168/168 [==============================] - ETA: 0s - loss: 0.
saving model to /content/drive/MyDrive/MLG/Model-2/Model-2.hdf5
# 168/168 [==============================] - 33s 198ms/step - loss: 0.4240 - acc: 0.4910 - mae: 0.1626 - val_loss: 0.3426 - val_acc: 0.4589 - val_mae: 0.1693
# Epoch 33/40
# 168/168 [==============================] - ETA: 0s - loss: 0.4239 - acc: 0.4911 - mae: 0.1625
# Epoch 33: val_loss did not improve from 0.34263
# 168/168 [==============================] - 33s 195ms/step - loss: 0.4239 - acc: 0.4911 - mae: 0.1625 - val_loss: 0.3426 - val_acc: 0.4582 - val_mae: 0.1689
# Epoch 34/40
# 168/168 [==============================] - ETA: 0s - loss: 0.4232 - acc: 0.4922 - mae: 0.1623
# Epoch 34: val_loss improved from 0.34263 to 0.34195, saving model to /content/drive/MyDrive/MLG/Model-2/Model-2.hdf5
# 168/168 [==============================] - 33s 198ms/step - loss: 0.4232 - acc: 0.4922 - mae: 0.1623 - val_loss: 0.3419 - val_acc: 0.4608 - val_mae: 0.1685
# Epoch 35/40
# 168/168 [==============================] - ETA: 0s - loss: 0.4231 - acc: 0.4925 - mae: 0.1622
# Epoch 35: val_loss did not improve from 0.34195
# 168/168 [==============================] - 33s 196ms/step - loss: 0.4231 - acc: 0.4925 - mae: 0.1622 - val_loss: 0.3423 - val_acc: 0.4602 - val_mae: 0.1670
# Epoch 36/40
# 168/168 [==============================] - ETA: 0s - loss: 0.4223 - acc: 0.4936 - mae: 0.1619
# Epoch 36: val_loss did not improve from 0.34195
# 168/168 [==============================] - 33s 199ms/step - loss: 0.4223 - acc: 0.4936 - mae: 0.1619 - val_loss: 0.3433 - val_acc: 0.4565 - val_mae: 0.1686
# Epoch 37/40
# 168/168 [==============================] - ETA: 0s - loss: 0.4221 - acc: 0.4941 - mae: 0.1619
# Epoch 37: val_loss did not improve from 0.34195
# 168/168 [==============================] - 33s 196ms/step - loss: 0.4221 - acc: 0.4941 - mae: 0.1619 - val_loss: 0.3423 - val_acc: 0.4613 - val_mae: 0.1672
# Epoch 38/40
# 168/168 [==============================] - ETA: 0s - loss: 0.4220 - acc: 0.4939 - mae: 0.1618
# Epoch 38: val_loss did not improve from 0.34195
# 168/168 [==============================] - 33s 195ms/step - loss: 0.4220 - acc: 0.4939 - mae: 0.1618 - val_loss: 0.3425 - val_acc: 0.4582 - val_mae: 0.1681
# Epoch 39/40
# 168/168 [==============================] - ETA: 0s - loss: 0.4210 - acc: 0.4956 - mae: 0.1614
# Epoch 39: val_loss improved from 0.34195 to 0.34095, saving model to /content/drive/MyDrive/MLG/Model-2/Model-2.hdf5
# 168/168 [==============================] - 33s 198ms/step - loss: 0.4210 - acc: 0.4956 - mae: 0.1614 - val_loss: 0.3409 - val_acc: 0.4612 - val_mae: 0.1682
# Epoch 40/40
# 168/168 [==============================] - ETA: 0s - loss: 0.4206 - acc: 0.4962 - mae: 0.1612
# Epoch 40: val_loss did not improve from 0.34095
# 168/168 [==============================] - 33s 195ms/step - loss: 0.4206 - acc: 0.4962 - mae: 0.1612 - val_loss: 0.3417 - val_acc: 0.4603 - val_mae: 0.1674

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 14, 10

# "Accuracy"
fig = plt.figure()
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# "Loss"
fig = plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
model.save("/content/drive/MyDrive/MLG/Model-2/D1.h5")
file = open("/content/drive/MyDrive/MLG/Model-2/D1.history", "wb")
pkl.dump(history, file)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://d21129e8-1c08-4f3c-b438-d38c1126b6ac/assets
# INFO:tensorflow:Assets written to: ram://d21129e8-1c08-4f3c-b438-d38c1126b6ac/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fc0a06b0450> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fc0a0695990> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
test_pred = model.predict(np.array([test_x[0]]))

# %%
plt.figure(figsize=(20,4))
plt.title("True")
plt.imshow(test_y[0][0:67].T)
plt.figure(figsize=(20,4))
plt.title("Predicted")
plt.imshow(test_pred[0][0:67].T)

# %%
import tensorflow
tensorflow.keras.utils.plot_model(
    model,
    to_file='model.png',
    show_shapes=True,
    show_dtype=True,
    show_layer_names=True,
    rankdir='TB',
    expand_nested=True,
    dpi=96,
    layer_range=None,
    show_layer_activations=True
)
