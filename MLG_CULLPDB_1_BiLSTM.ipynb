# %% [markdown]
# # ML in Genomics
# ## BiLSTM-2 Training
# ### Team Members:
#     1. Hrishikesh Mahajan
#     2. Pratik Kamble
#     3. Smridhi Bhat
#     4. Yash Shekhadar

# %%
# Basic Imports
import gzip as gz
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from random import random
import pickle as pkl

# Keras Imports 
from keras.models import Sequential
from keras.layers import LSTM, Bidirectional
from keras.layers import Dense
from keras.layers import Masking
from keras.regularizers import l2
from keras.layers import Dropout
from keras import optimizers
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
f = gz.GzipFile("/content/drive/MyDrive/MLG/CULLPDB-Train.npy.gz", "r")
train_raw = np.load(f)
train_data = train_raw.reshape((len(train_raw), 700, 57))
train_x = train_data[:, :, 0:21]
train_y = train_data[:, :, 22:30]

# %%
f = gz.GzipFile("/content/drive/MyDrive/MLG/CULLPDB-Test.npy.gz", "r")
test_raw = np.load(f)
test_data = test_raw.reshape((len(test_raw), 700, 57))
test_x = test_data[:, :, 0:21]
test_y = test_data[:, :, 22:30]

# %%
model = Sequential()
model.add(Masking(mask_value=0., input_shape=(700, 21)))
model.add(Bidirectional(LSTM(128, return_sequences=True)))
model.add(Bidirectional(LSTM(128, return_sequences=True)))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation ='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc',  'mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  masking (Masking)           (None, 700, 21)           0
#
#  bidirectional (Bidirectiona  (None, 700, 256)         153600
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 700, 256)         394240
#  nal)
#
#  dense (Dense)               (None, 700, 64)           16448
#
#  dense_1 (Dense)             (None, 700, 32)           2080
#
#  dense_2 (Dense)             (None, 700, 16)           528
#
#  dense_3 (Dense)             (None, 700, 8)            136
#
# =================================================================
# Total params: 567,032
# Trainable params: 567,032
# Non-trainable params: 0
# _________________________________________________________________

# %%
filepath = '/content/drive/MyDrive/MLG/Model-3/Model-3.hdf5'
checkpoint = ModelCheckpoint(filepath=filepath, 
                             monitor='val_loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')

# %%
history = model.fit(train_x, train_y, epochs=40, validation_data = (test_x, test_y), batch_size=32,callbacks=[checkpoint])
# Out:
# Epoch 1/40
# 168/168 [==============================] - ETA: 0s - loss: 0.5316 - acc: 0.3804 - mae: 0.1927
# Epoch 1: val_loss improved from inf to 0.36595, saving model to /content/drive/MyDrive/MLG/Model-3/Model-3.hdf5
# 168/168 [==============================] - 101s 450ms/step - loss: 0.5316 - acc: 0.3804 - mae: 0.1927 - val_loss: 0.3660 - val_acc: 0.4601 - val_mae: 0.1774
# Epoch 2/40
# 168/168 [==============================] - ETA: 0s - loss: 0.4282 - acc: 0.5020 - mae: 0.1605
# Epoch 2: val_loss improved from 0.36595 to 0.32107, saving model to /content/drive/MyDrive/MLG/Model-3/Model-3.hdf5
# 168/168 [==============================] - 63s 377ms/step - loss: 0.4282 - acc: 0.5020 - mae: 0.1605 - val_loss: 0.3211 - val_acc: 0.4962 - val_mae: 0.1571
# Epoch 3/40
# 168/168 [==============================] - ETA: 0s - loss: 0.3970 - acc: 0.5272 - mae: 0.1522
# Epoch 3: val_loss improved from 0.32107 to 0.31875, saving model to /content/drive/MyDrive/MLG/Model-3/Model-3.hdf5
# 168/168 [==============================] - 63s 378ms/step - loss: 0.3970 - acc: 0.5272 - mae: 0.1522 - val_loss: 0.3188 - val_acc: 0.4975 - val_mae: 0.1571
# Epoch 4/40
# 168/168 [==============================] - ETA: 0s - loss: 0.3902 - acc: 0.5363 - mae: 0.1497
# Epoch 4: val_loss improved from 0.31875 to 0.31351, saving model to /content/drive/MyDrive/MLG/Model-3/Model-3.hdf5
# 168/168 [==============================] - 63s 372ms/step - loss: 0.3902 - acc: 0.5363 - mae: 0.1497 - val_loss: 0.3135 - val_acc: 0.5098 - val_mae: 0.1573
# Epoch 5/40
# 168/168 [==============================] - ETA: 0s - loss: 0.3862 - acc: 0.5412 - mae: 0.1484
# Epoch 5: val_loss improved from 0.31351 to 0.30853, saving model to /content/drive/MyDrive/MLG/Model-3/Model-3.hdf5
# 168/168 [==============================] - 63s 374ms/step - loss: 0.3862 - acc: 0.5412 - mae: 0.1484 - val_loss: 0.3085 - val_acc: 0.5160 - val_mae: 0.1521
# Epoch 6/40
# 168/168 [==============================] - ETA: 0s - loss: 0.3819 - acc: 0.5457 - mae: 0.1467
# Epoch 6: val_loss improved from 0.30853 to 0.30759, saving model to /content/drive/MyDrive/MLG/Model-3/Model-3.hdf5
# 168/168 [==============================] - 63s
val_loss did not improve from 0.28482
# 168/168 [==============================] - 63s 373ms/step - loss: 0.2906 - acc: 0.6556 - mae: 0.1132 - val_loss: 0.3002 - val_acc: 0.5527 - val_mae: 0.1345
# Epoch 32/40
# 168/168 [==============================] - ETA: 0s - loss: 0.2872 - acc: 0.6596 - mae: 0.1121
# Epoch 32: val_loss did not improve from 0.28482
# 168/168 [==============================] - 64s 379ms/step - loss: 0.2872 - acc: 0.6596 - mae: 0.1121 - val_loss: 0.3068 - val_acc: 0.5503 - val_mae: 0.1336
# Epoch 33/40
# 168/168 [==============================] - ETA: 0s - loss: 0.2826 - acc: 0.6643 - mae: 0.1105
# Epoch 33: val_loss did not improve from 0.28482
# 168/168 [==============================] - 63s 374ms/step - loss: 0.2826 - acc: 0.6643 - mae: 0.1105 - val_loss: 0.3099 - val_acc: 0.5458 - val_mae: 0.1348
# Epoch 34/40
# 168/168 [==============================] - ETA: 0s - loss: 0.2790 - acc: 0.6682 - mae: 0.1093
# Epoch 34: val_loss did not improve from 0.28482
# 168/168 [==============================] - 63s 373ms/step - loss: 0.2790 - acc: 0.6682 - mae: 0.1093 - val_loss: 0.3130 - val_acc: 0.5474 - val_mae: 0.1328
# Epoch 35/40
# 168/168 [==============================] - ETA: 0s - loss: 0.2759 - acc: 0.6713 - mae: 0.1083
# Epoch 35: val_loss did not improve from 0.28482
# 168/168 [==============================] - 63s 374ms/step - loss: 0.2759 - acc: 0.6713 - mae: 0.1083 - val_loss: 0.3161 - val_acc: 0.5474 - val_mae: 0.1336
# Epoch 36/40
# 168/168 [==============================] - ETA: 0s - loss: 0.2712 - acc: 0.6764 - mae: 0.1068
# Epoch 36: val_loss did not improve from 0.28482
# 168/168 [==============================] - 63s 372ms/step - loss: 0.2712 - acc: 0.6764 - mae: 0.1068 - val_loss: 0.3203 - val_acc: 0.5481 - val_mae: 0.1316
# Epoch 37/40
# 168/168 [==============================] - ETA: 0s - loss: 0.2699 - acc: 0.6775 - mae: 0.1063
# Epoch 37: val_loss did not improve from 0.28482
# 168/168 [==============================] - 63s 374ms/step - loss: 0.2699 - acc: 0.6775 - mae: 0.1063 - val_loss: 0.3215 - val_acc: 0.5444 - val_mae: 0.1330
# Epoch 38/40
# 168/168 [==============================] - ETA: 0s - loss: 0.2646 - acc: 0.6833 - mae: 0.1046
# Epoch 38: val_loss did not improve from 0.28482
# 168/168 [==============================] - 63s 374ms/step - loss: 0.2646 - acc: 0.6833 - mae: 0.1046 - val_loss: 0.3300 - val_acc: 0.5413 - val_mae: 0.1323
# Epoch 39/40
# 168/168 [==============================] - ETA: 0s - loss: 0.2613 - acc: 0.6866 - mae: 0.1034
# Epoch 39: val_loss did not improve from 0.28482
# 168/168 [==============================] - 63s 374ms/step - loss: 0.2613 - acc: 0.6866 - mae: 0.1034 - val_loss: 0.3333 - val_acc: 0.5407 - val_mae: 0.1331
# Epoch 40/40
# 168/168 [==============================] - ETA: 0s - loss: 0.2573 - acc: 0.6909 - mae: 0.1020
# Epoch 40: val_loss did not improve from 0.28482
# 168/168 [==============================] - 62s 371ms/step - loss: 0.2573 - acc: 0.6909 - mae: 0.1020 - val_loss: 0.3355 - val_acc: 0.5391 - val_mae: 0.1334

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 14, 10

# "Accuracy"
fig = plt.figure()
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# "Loss"
fig = plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
model.save("/content/drive/MyDrive/MLG/Model-3/D3.h5")
file = open("/content/drive/MyDrive/MLG/Model-3/D3.history", "wb")
pkl.dump(history, file)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://4482197a-e55f-43bf-8859-99651578e3d5/assets
# INFO:tensorflow:Assets written to: ram://4482197a-e55f-43bf-8859-99651578e3d5/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f907026f4d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f9070213190> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f906f175d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f906ef9ced0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
test_pred = model.predict(np.array([test_x[0]]))

# %%
plt.figure(figsize=(20,4))
plt.title("True")
plt.imshow(test_y[0][0:67].T)
plt.figure(figsize=(20,4))
plt.title("Predicted")
plt.imshow(test_pred[0][0:67].T)

# %%
import tensorflow
tensorflow.keras.utils.plot_model(
    model,
    to_file='model.png',
    show_shapes=True,
    show_dtype=True,
    show_layer_names=True,
    rankdir='TB',
    expand_nested=True,
    dpi=96,
    layer_range=None,
    show_layer_activations=True
)
